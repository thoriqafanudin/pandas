# %%
import pandas as pd

# %%
data = pd.read_excel('data_excel.xlsx')
data
# Out:
#      TAHUN         NAMA PROVINSI NAMA KABUPATEN/KOTA   NAMA KECAMATAN  \
# 0     2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU UTR
# 1     2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU UTR
# 2     2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU UTR
# 3     2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU SLT
# 4     2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU SLT
# ..     ...                   ...                 ...              ...
# 262   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR         CIPAYUNG
# 263   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR         CIPAYUNG
# 264   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR         CIPAYUNG
# 265   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR         CIPAYUNG
# 266   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR         CIPAYUNG
#
#      NAMA KELURAHAN  LUAS WILAYAH (KM2)  KEPADATAN (JIWA/KM2)  \
# 0       P. PANGGANG                0.91                  6779
# ...

# %%
data_baru = data['NAMA KELURAHAN']
type(data_baru)
# Out:
# pandas.core.series.Series

# %%
data_baru
# Out:
# 0         P. PANGGANG
# 1           P. KELAPA
# 2          P. HARAPAN
# 3      P. UNTUNG JAWA
# 4           P. TIDUNG
#             ...
# 262            MUNJUL
# 263              SETU
# 264        BAMBU APUS
# 265      LUBANG BUAYA
# 266             CEGER
# Name: NAMA KELURAHAN, Length: 267, dtype: object

# %%
data['LUAS WILAYAH (KM2)']
# Out:
# 0      0.91
# 1      3.76
# 2      3.59
# 3      0.59
# 4      1.57
#        ...
# 262    1.90
# 263    3.25
# 264    3.17
# 265    3.72
# 266    3.63
# Name: LUAS WILAYAH (KM2), Length: 267, dtype: float64

# %%
data[['LUAS WILAYAH (KM2)']]
# Out:
#      LUAS WILAYAH (KM2)
# 0                  0.91
# 1                  3.76
# 2                  3.59
# 3                  0.59
# 4                  1.57
# ..                  ...
# 262                1.90
# 263                3.25
# 264                3.17
# 265                3.72
# 266                3.63
#
# [267 rows x 1 columns]

# %%
data[['NAMA KELURAHAN', 'LUAS WILAYAH (KM2)']]
# Out:
#      NAMA KELURAHAN  LUAS WILAYAH (KM2)
# 0       P. PANGGANG                0.91
# 1         P. KELAPA                3.76
# 2        P. HARAPAN                3.59
# 3    P. UNTUNG JAWA                0.59
# 4         P. TIDUNG                1.57
# ..              ...                 ...
# 262          MUNJUL                1.90
# 263            SETU                3.25
# 264      BAMBU APUS                3.17
# 265    LUBANG BUAYA                3.72
# 266           CEGER                3.63
#
# [267 rows x 2 columns]

# %% [markdown]
# # dot notation

# %%
data.TAHUN
# Out:
# 0      2013
# 1      2013
# 2      2013
# 3      2013
# 4      2013
#        ...
# 262    2013
# 263    2013
# 264    2013
# 265    2013
# 266    2013
# Name: TAHUN, Length: 267, dtype: int64

# %%
data.TAHUN.equals(data['TAHUN'])
# Out:
# True

# %% [markdown]
# # .iloc

# %%
data.iloc[0:11]
# Out:
#     TAHUN         NAMA PROVINSI NAMA KABUPATEN/KOTA   NAMA KECAMATAN  \
# 0    2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU UTR
# 1    2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU UTR
# 2    2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU UTR
# 3    2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU SLT
# 4    2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU SLT
# 5    2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU SLT
# 6    2013  PROVINSI DKI JAKARTA       JAKARTA PUSAT           GAMBIR
# 7    2013  PROVINSI DKI JAKARTA       JAKARTA PUSAT           GAMBIR
# 8    2013  PROVINSI DKI JAKARTA       JAKARTA PUSAT           GAMBIR
# 9    2013  PROVINSI DKI JAKARTA       JAKARTA PUSAT           GAMBIR
# 10   2013  PROVINSI DKI JAKARTA       JAKARTA PUSAT           GAMBIR
#
#     NAMA KELURAHAN  LUAS WILAYAH (KM2)  KEPADATAN (JIWA/KM2)  35-39 Laki-Laki  \
# ...

# %%
data.iloc[:, 3:5]
# Out:
#       NAMA KECAMATAN  NAMA KELURAHAN
# 0    KEP. SERIBU UTR     P. PANGGANG
# 1    KEP. SERIBU UTR       P. KELAPA
# 2    KEP. SERIBU UTR      P. HARAPAN
# 3    KEP. SERIBU SLT  P. UNTUNG JAWA
# 4    KEP. SERIBU SLT       P. TIDUNG
# ..               ...             ...
# 262         CIPAYUNG          MUNJUL
# 263         CIPAYUNG            SETU
# 264         CIPAYUNG      BAMBU APUS
# 265         CIPAYUNG    LUBANG BUAYA
# 266         CIPAYUNG           CEGER
#
# [267 rows x 2 columns]

# %%
data.iloc[:, -1]
# Out:
# 0       27
# 1        8
# 2       26
# 3       13
# 4       17
#       ...
# 262     51
# 263     64
# 264     84
# 265    165
# 266     44
# Name: >75  Perempuan, Length: 267, dtype: int64

# %%
data.iloc[-5:]
# Out:
#      TAHUN         NAMA PROVINSI NAMA KABUPATEN/KOTA NAMA KECAMATAN  \
# 262   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR       CIPAYUNG
# 263   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR       CIPAYUNG
# 264   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR       CIPAYUNG
# 265   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR       CIPAYUNG
# 266   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR       CIPAYUNG
#
#     NAMA KELURAHAN  LUAS WILAYAH (KM2)  KEPADATAN (JIWA/KM2)  35-39 Laki-Laki  \
# 262         MUNJUL                1.90                 12734             1167
# 263           SETU                3.25                  6028              937
# 264     BAMBU APUS                3.17                  8400             1242
# 265   LUBANG BUAYA                3.72                 18055             3258
# 266          CEGER                3.63                  5492             1007
#
#      35-39 Perempuan  40-44 Laki-Laki  ...  55-59 Laki-Laki  55-59 Perempuan  \
# ...

# %%
data.tail()
# Out:
#      TAHUN         NAMA PROVINSI NAMA KABUPATEN/KOTA NAMA KECAMATAN  \
# 262   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR       CIPAYUNG
# 263   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR       CIPAYUNG
# 264   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR       CIPAYUNG
# 265   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR       CIPAYUNG
# 266   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR       CIPAYUNG
#
#     NAMA KELURAHAN  LUAS WILAYAH (KM2)  KEPADATAN (JIWA/KM2)  35-39 Laki-Laki  \
# 262         MUNJUL                1.90                 12734             1167
# 263           SETU                3.25                  6028              937
# 264     BAMBU APUS                3.17                  8400             1242
# 265   LUBANG BUAYA                3.72                 18055             3258
# 266          CEGER                3.63                  5492             1007
#
#      35-39 Perempuan  40-44 Laki-Laki  ...  55-59 Laki-Laki  55-59 Perempuan  \
# ...

# %%
data.iloc[[2, 4, 6]]
# Out:
#    TAHUN         NAMA PROVINSI NAMA KABUPATEN/KOTA   NAMA KECAMATAN  \
# 2   2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU UTR
# 4   2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU SLT
# 6   2013  PROVINSI DKI JAKARTA       JAKARTA PUSAT           GAMBIR
#
#   NAMA KELURAHAN  LUAS WILAYAH (KM2)  KEPADATAN (JIWA/KM2)  35-39 Laki-Laki  \
# 2     P. HARAPAN                3.59                   628              255
# 4      P. TIDUNG                1.57                  3084               98
# 6         GAMBIR                2.58                  1350              166
#
#    35-39 Perempuan  40-44 Laki-Laki  ...  55-59 Laki-Laki  55-59 Perempuan  \
# 2              238              232  ...              139              101
# 4               75               73  ...               37               32
# 6              174              130  ...              108               90
#
#    60-64 Laki-Laki  60-64 Perempuan  65-69 Laki-Laki  65-69 Perempuan  \
# ...

# %% [markdown]
# # .loc

# %%
data_baru = pd.read_excel('data_excel.xlsx', index_col='NAMA KECAMATAN')
data_baru
# Out:
#                  TAHUN         NAMA PROVINSI NAMA KABUPATEN/KOTA  \
# NAMA KECAMATAN
# KEP. SERIBU UTR   2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU
# KEP. SERIBU UTR   2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU
# KEP. SERIBU UTR   2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU
# KEP. SERIBU SLT   2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU
# KEP. SERIBU SLT   2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU
# ...                ...                   ...                 ...
# CIPAYUNG          2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR
# CIPAYUNG          2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR
# CIPAYUNG          2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR
# CIPAYUNG          2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR
# CIPAYUNG          2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR
#
#                  NAMA KELURAHAN  LUAS WILAYAH (KM2)  KEPADATAN (JIWA/KM2)  \
# NAMA KECAMATAN
# KEP. SERIBU UTR     P. PANGGANG                0.91                  6779
# ...

# %%
data_baru.loc['CIPAYUNG']
# Out:
#                 TAHUN         NAMA PROVINSI NAMA KABUPATEN/KOTA  \
# NAMA KECAMATAN
# CIPAYUNG         2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR
# CIPAYUNG         2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR
# CIPAYUNG         2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR
# CIPAYUNG         2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR
# CIPAYUNG         2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR
# CIPAYUNG         2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR
# CIPAYUNG         2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR
# CIPAYUNG         2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR
#
#                 NAMA KELURAHAN  LUAS WILAYAH (KM2)  KEPADATAN (JIWA/KM2)  \
# NAMA KECAMATAN
# CIPAYUNG              CIPAYUNG                3.08                  8441
# CIPAYUNG             CILANGKAP                6.03                  4396
# CIPAYUNG        PONDOK RANGGON                3.66                  6772
# ...

# %%
data_baru.loc[['CIPAYUNG', 'GAMBIR'], ['NAMA KELURAHAN', 'LUAS WILAYAH (KM2)']]
# Out:
#                 NAMA KELURAHAN  LUAS WILAYAH (KM2)
# NAMA KECAMATAN
# CIPAYUNG              CIPAYUNG                3.08
# CIPAYUNG             CILANGKAP                6.03
# CIPAYUNG        PONDOK RANGGON                3.66
# CIPAYUNG                MUNJUL                1.90
# CIPAYUNG                  SETU                3.25
# CIPAYUNG            BAMBU APUS                3.17
# CIPAYUNG          LUBANG BUAYA                3.72
# CIPAYUNG                 CEGER                3.63
# GAMBIR                  GAMBIR                2.58
# GAMBIR                  CIDENG                1.26
# GAMBIR            PETOJO UTARA                1.12
# GAMBIR          PETOJO SELATAN                1.14
# GAMBIR            KEBON KELAPA                0.78
# GAMBIR               DURI PULO                0.72
