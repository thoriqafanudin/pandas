# %% [markdown]
# # KEPADATAN PENDUDUK JAKARTA

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('data_excel.xlsx')

# %%
data
# Out:
#      TAHUN         NAMA PROVINSI NAMA KABUPATEN/KOTA   NAMA KECAMATAN  \
# 0     2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU UTR
# 1     2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU UTR
# 2     2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU UTR
# 3     2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU SLT
# 4     2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU SLT
# ..     ...                   ...                 ...              ...
# 262   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR         CIPAYUNG
# 263   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR         CIPAYUNG
# 264   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR         CIPAYUNG
# 265   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR         CIPAYUNG
# 266   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR         CIPAYUNG
#
#      NAMA KELURAHAN  LUAS WILAYAH (KM2)  KEPADATAN (JIWA/KM2)  \
# 0       P. PANGGANG                0.91                  6779
# ...

# %%
luas = data['LUAS WILAYAH (KM2)']
luas
# Out:
# 0      0.91
# 1      3.76
# 2      3.59
# 3      0.59
# 4      1.57
#        ...
# 262    1.90
# 263    3.25
# 264    3.17
# 265    3.72
# 266    3.63
# Name: LUAS WILAYAH (KM2), Length: 267, dtype: float64

# %%
luas.describe()
# Out:
# count    267.000000
# mean       2.487378
# std        2.109983
# min        0.270000
# 25%        0.965000
# 50%        1.800000
# 75%        3.315000
# max       13.070000
# Name: LUAS WILAYAH (KM2), dtype: float64

# %%
luas.count()
# Out:
# 267

# %%
luas.mean()
# Out:
# 2.487378277153557

# %%
luas.median()
# Out:
# 1.8

# %%
luas.sum()
# Out:
# 664.1300000000001

# %%
sum(luas)
# Out:
# 664.1299999999998

# %%
luas.sum(skipna=True)
# Out:
# 664.1300000000001

# %%
luas.sum(skipna=False)
# Out:
# 664.1300000000001

# %%
luas.std()
# Out:
# 2.1099825078507455

# %%
data2 = data.dropna()
data2
# Out:
#      TAHUN         NAMA PROVINSI NAMA KABUPATEN/KOTA   NAMA KECAMATAN  \
# 0     2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU UTR
# 1     2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU UTR
# 2     2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU UTR
# 3     2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU SLT
# 4     2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU SLT
# ..     ...                   ...                 ...              ...
# 262   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR         CIPAYUNG
# 263   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR         CIPAYUNG
# 264   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR         CIPAYUNG
# 265   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR         CIPAYUNG
# 266   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR         CIPAYUNG
#
#      NAMA KELURAHAN  LUAS WILAYAH (KM2)  KEPADATAN (JIWA/KM2)  \
# 0       P. PANGGANG                0.91                  6779
# ...

# %%
dataku = pd.read_csv('kepadatan.csv')
dataku
# Out:
#      TAHUN         NAMA PROVINSI NAMA KABUPATEN/KOTA   NAMA KECAMATAN  \
# 0     2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU UTR
# 1     2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU UTR
# 2     2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU UTR
# 3     2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU SLT
# 4     2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU SLT
# ..     ...                   ...                 ...              ...
# 262   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR         CIPAYUNG
# 263   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR         CIPAYUNG
# 264   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR         CIPAYUNG
# 265   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR         CIPAYUNG
# 266   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR         CIPAYUNG
#
#      NAMA KELURAHAN  LUAS WILAYAH (KM2)  KEPADATAN (JIWA/KM2)  Unnamed: 7  \
# ...

# %%
dataku2 = dataku.dropna(axis=1)
dataku2
# Out:
#      TAHUN         NAMA PROVINSI NAMA KABUPATEN/KOTA   NAMA KECAMATAN  \
# 0     2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU UTR
# 1     2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU UTR
# 2     2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU UTR
# 3     2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU SLT
# 4     2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU SLT
# ..     ...                   ...                 ...              ...
# 262   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR         CIPAYUNG
# 263   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR         CIPAYUNG
# 264   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR         CIPAYUNG
# 265   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR         CIPAYUNG
# 266   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR         CIPAYUNG
#
#      NAMA KELURAHAN  LUAS WILAYAH (KM2)  KEPADATAN (JIWA/KM2)  \
# 0       P. PANGGANG                0.91                  6779
# ...

# %%
dataku3 = dataku.dropna(thresh=9)
dataku3
# Out:
#      TAHUN         NAMA PROVINSI NAMA KABUPATEN/KOTA   NAMA KECAMATAN  \
# 0     2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU UTR
# 1     2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU UTR
# 2     2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU UTR
# 3     2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU SLT
# 4     2013  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU SLT
# ..     ...                   ...                 ...              ...
# 262   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR         CIPAYUNG
# 263   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR         CIPAYUNG
# 264   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR         CIPAYUNG
# 265   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR         CIPAYUNG
# 266   2013  PROVINSI DKI JAKARTA       JAKARTA TIMUR         CIPAYUNG
#
#      NAMA KELURAHAN  LUAS WILAYAH (KM2)  KEPADATAN (JIWA/KM2)  Unnamed: 7  \
# ...

# %%
dataku4 = dataku3

# %%
data_mean = dataku4['LUAS WILAYAH (KM2)'].mean()
dataku4['Unnamed: 7']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 262   NaN
# 263   NaN
# 264   NaN
# 265   NaN
# 266   NaN
# Name: Unnamed: 7, Length: 267, dtype: float64

# %%
dataku4['Unnamed: 7'].fillna(value=data_mean)
# Out:
# 0      2.487378
# 1      2.487378
# 2      2.487378
# 3      2.487378
# 4      2.487378
#          ...
# 262    2.487378
# 263    2.487378
# 264    2.487378
# 265    2.487378
# 266    2.487378
# Name: Unnamed: 7, Length: 267, dtype: float64

# %%
type(dataku4['LUAS WILAYAH (KM2)'])
# Out:
# pandas.core.series.Series

# %%
dataku4['LUAS WILAYAH (KM2)'].values
# Out:
# array([ 0.91,  3.76,  3.59,  0.59,  1.57,  1.39,  2.58,  1.26,  1.12,
#         1.14,  0.78,  0.72,  1.89,  0.51,  0.55,  1.98,  1.29,  0.55,
#         1.13,  0.91,  0.82,  0.53,  0.99,  1.15,  1.05,  0.81,  0.91,
#         0.71,  0.71,  0.45,  0.64,  2.22,  1.22,  1.25,  2.44,  0.98,
#         0.82,  1.46,  0.83,  2.59,  1.58,  1.53,  0.9 ,  1.26,  0.71,
#         0.73,  1.19,  0.3 ,  0.27,  0.62,  3.95, 10.53, 10.56,  3.23,
#         7.71,  5.59,  4.68,  2.8 ,  2.36,  1.73,  6.65,  1.09,  3.27,
#         2.37,  1.58,  1.33,  1.86,  1.33,  8.31,  5.61,  7.92,  2.47,
#         3.17, 10.64,  4.44,  2.61,  3.53,  5.77,  5.31,  6.28,  4.53,
#         4.26,  5.03,  4.67,  2.61,  7.18,  4.18,  1.22,  1.11,  1.88,
#         1.44,  1.76,  1.44,  2.61,  0.68,  0.55,  0.59,  0.37,  0.51,
#         0.32,  0.38,  0.96,  0.28,  0.32,  0.4 ,  0.62,  0.32,  0.55,
#         0.8 ,  0.46,  0.78,  0.53,  0.42,  2.69,  1.6 ,  1.57,  1.5 ,
# ...

# %%
type(dataku4['LUAS WILAYAH (KM2)'].values)
# Out:
# numpy.ndarray
